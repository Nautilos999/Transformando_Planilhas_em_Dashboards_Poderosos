# %%
df = spark.sql("SELECT * FROM vendas_delivery.silver.canais")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.dim_canais")

df = spark.sql("SELECT * FROM vendas_delivery.silver.centro_de_distribuicao")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.dim_centro_de_distribuicao")

df = spark.sql("SELECT * FROM vendas_delivery.silver.entregador")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.dim_entregador")

df = spark.sql("SELECT * FROM vendas_delivery.silver.entregas")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.dim_entregas")

df = spark.sql("SELECT * FROM vendas_delivery.silver.lojas")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.dim_lojas")

df = spark.sql("SELECT * FROM vendas_delivery.silver.pagamentos")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.fato_pagamentos")

df = spark.sql("SELECT * FROM vendas_delivery.silver.pedidos")
df.write.mode("overwrite").saveAsTable("vendas_delivery.producao.fato_pedidos")
